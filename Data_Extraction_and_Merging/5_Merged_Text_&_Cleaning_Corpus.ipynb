# %%
from collections import Counter
import pandas as pd
import re

# %% [markdown]
# ## Merging the other_dataset and the Guardian Dataset.

# %%
# Load both files. 
df1 = pd.read_csv("/Users/henryasiamah/Desktop/work/new_other_dataset.csv")
df2 = pd.read_csv("/Users/henryasiamah/Desktop/work/filtered_guardian_news.csv")

# Rename Columns in df2 to match columns in df1.
df2 = df2.rename(columns={'publication_date_fixed': 'Date', 'webTitle': 'Headline', 'body': 'Content', 'News Paper Source': 'Source'})

# Add a new column to df2: Country/Organization and set it to UK
df2["Country/Organization"] = 'UK'

# Select columns in df1 that matches desired columns in df2.
df1 = df1[['Date', 'Headline', 'Content', 'Source', 'Country/Organization']]

#load df2
df2 = df2[['Date', 'Headline', 'Content', 'Source', 'Country/Organization']]

#Concatenate the two dataframes vertically.
final_df = pd.concat([df1, df2])

#Convert the 'Date' column to datetime format.
final_df['Date'] = pd.to_datetime(final_df['Date'], errors='coerce')

#print the original number of rows and columns for df1 and df2
print("Original number of rows and columns for df1:")
print(df1.shape)
print("Original number of rows and columns for df2:")
print(df2.shape)

#print the number of rows and columns for the final_df or merged dataset.
print("Number of rows and columns for the final dataframe")
print(final_df.shape)

#fill missing values for empty string
final_df.fillna('', inplace=True)
# Out:
# Original number of rows and columns for df1:
# (2488, 5)
# Original number of rows and columns for df2:
# (2967, 5)
# Number of rows and columns for the final dataframe
# (5455, 5)

# %%
final_df.head()
# Out:
#         Date     Headline                                            Content  \
# 0 2024-06-07  www.bbc.com  How many people cross the Channel in small boa...
# 1 2024-06-07  www.bbc.com  Far right eyes Europe vote surge and ditches G...
# 2 2024-06-07  www.bbc.com  Greek court throws out shipwreck trial against...
# 3 2024-06-07  www.bbc.com  Migrants cross Channel for 10th consecutive da...
# 4 2024-06-07  www.bbc.com  More than 700 people arrive by small boats in ...
#
#   Source Country/Organization
# 0    BBC                   UK
# 1    BBC                   UK
# 2    BBC                   UK
# 3    BBC                   UK
# 4    BBC                   UK

# %%
final_df.tail()
# Out:
#            Date                                           Headline  \
# 2962 2021-04-22  Orange-bellied parrots leave Tasmania in bigge...
# 2963 2021-04-21  Melting ice in Arctic linked to bowhead whales...
# 2964 2021-03-01  A birder's calendar: where and when to watch A...
# 2965 2021-01-15  Air pollution will lead to mass migration, say...
# 2966 2021-01-17  In brief: Passing: An Alternative History of I...
#
#                                                 Content        Source  \
# 2962  <p>Nearly 200 endangered orange-bellied parrot...  The Guardian
# 2963  <p>As the ice melts at pace in the Arctic, the...  The Guardian
# 2964  <p>During Covid lockdown, birds in our backyar...  The Guardian
# 2965  <p>Air pollution does not respect national bou...  The Guardian
# 2966  <h2><strong><a href="https://guardianbookshop....  The Guardian
#
#      Country/Organization
# 2962                   UK
# 2963                   UK
# 2964                   UK
# 2965                   UK
# 2966                   UK

# %%
final_df.count()
# Out:
# Date                    5455
# Headline                5455
# Content                 5455
# Source                  5455
# Country/Organization    5455
# dtype: int64

# %%
final_df.to_csv("/Users/henryasiamah/Desktop/work/final_df.csv", index = False)

# %% [markdown]
# # Text Cleaning

# %%
df = final_df

# %%
df.duplicated(subset=['Content']).sum()
# Out:
# 166

# %%
df.drop_duplicates(subset=['Content'], inplace=True)

# %%
# Remove rows with NaN values in 'Cotent' column
df.dropna(subset=['Content'], inplace=True)

# Remove rows with 'NaN' values in 'Content'column
df = df[~df['Content'].isin(['NaN'])]

#print the cleaned dataset
print('The cleaned dataframe ahs {} rows and {} columns'.format(df.shape[0], df.shape[1]))
# Out:
# The cleaned dataframe ahs 5289 rows and 5 columns

# %%
df.head(10)
# Out:
#         Date         Headline  \
# 0 2024-06-07      www.bbc.com
# 1 2024-06-07      www.bbc.com
# 2 2024-06-07      www.bbc.com
# 3 2024-06-07      www.bbc.com
# 4 2024-06-07      www.bbc.com
# 5 2024-06-07      www.bbc.com
# 6 2024-06-07      www.bbc.com
# 7 2024-06-07      www.bbc.com
# 8 2024-06-07      www.bbc.com
# 9 2024-10-08  www.thelocal.fr
#
#                                              Content              Source  \
# 0  How many people cross the Channel in small boa...                 BBC
# 1  Far right eyes Europe vote surge and ditches G...                 BBC
# 2  Greek court throws out shipwreck trial against...                 BBC
# 3  Migrants cross Channel for 10th consecutive da...                 BBC
# 4  More than 700 people arrive by small boats in ...                 BBC
# 5  Small boats migrant arrivals top 7,500 this ye...                 BBC
# 6  Fourth man arrested in Channel deaths investig...                 BBC
# 7  Migrants: TUV distances itself from Reform UK ...                 BBC
# 8  Two males in court over Channel deaths investi...                 BBC
# 9  Asylum seekers, immigrants, refugees, foreigne...  The Local (France)
#
#   Country/Organization
# 0                   UK
# 1                   UK
# 2                   UK
# 3                   UK
# 4                   UK
# 5                   UK
# 6                   UK
# 7                   UK
# 8                   UK
# 9               France

# %%
df.tail(10)
# Out:
#            Date                                           Headline  \
# 2957 2021-01-11  'There is no noise': inside the controversial ...
# 2958 2021-06-26  Ancestors by Alice Roberts review – a story of...
# 2959 2021-02-01  Hong Kong migration agents report rush of inqu...
# 2960 2021-04-12   ‘My son could die’: the disabled Syrian refug...
# 2961 2021-02-04  Migration firm investigated over ads promising...
# 2962 2021-04-22  Orange-bellied parrots leave Tasmania in bigge...
# 2963 2021-04-21  Melting ice in Arctic linked to bowhead whales...
# 2964 2021-03-01  A birder's calendar: where and when to watch A...
# 2965 2021-01-15  Air pollution will lead to mass migration, say...
# 2966 2021-01-17  In brief: Passing: An Alternative History of I...
#
#                                                 Content        Source  \
# 2957  <p>I wanted to come here. No one forced me, an...  The Guardian
# 2958  <p>In 2002, not far from Amesbury in southern ...  The Guardian
# 2959  <p>Migration agents in Hong Kong say they have...  The Guardian
# 2960  <p>In January, the <a href="https://www.thegua...  The Guardian
# 2961  <p>An international migration firm is being in...  The Guardian
# 2962  <p>Nearly 200 endangered orange-bellied parrot...  The Guardian
# 2963  <p>As the ice melts at pace in the Arctic, the...  The Guardian
# 2964  <p>During Covid lockdown, birds in our backyar...  The Guardian
# 2965  <p>Air pollution does not respect national bou...  The Guardian
# 2966  <h2><strong><a href="https://guardianbookshop....  The Guardian
#
#      Country/Organization
# 2957                   UK
# 2958                   UK
# 2959                   UK
# 2960                   UK
# 2961                   UK
# 2962                   UK
# 2963                   UK
# 2964                   UK
# 2965                   UK
# 2966                   UK

# %% [markdown]
# ## Most Common Words
#
# Creating an overview of the most common words in the corpus.

# %%
# Concatenate all the strings in the 'Content' column into a single string
all_text = ' '.join(df['Content'].values)

# Use the counter class from the collections module to count the occurences of each word
word_counts = Counter(all_text.split())

# Get the 1000 most common words and their counts
most_common = word_counts.most_common(10000)

# Convert the results to a Pandas DataFrame for easier manipulation and printing
most_common_df = pd.DataFrame(most_common, columns=['Word', 'Count'])

# Print the DataFrame with the most common words and their counts in descending order
print(most_common_df.sort_values('Count', ascending=False))
# Out:
#             Word   Count
# 0            the  232039
# 1             to  141965
# 2             of  111019
# 3            and  100862
# 4             in   89933
# ...          ...     ...
# 9980      namely      30
# 9979  favourable      30
# 9978   disaster.      30
# 9977   Democracy      30
# 9999           à      30
#
# [10000 rows x 2 columns]

# %%
most_common_df.to_csv("/Users/henryasiamah/Desktop/work/most_common_words.csv", index = False)

# %%
#Define a function to clean the text. 
def clean_text(text):
    
    # Remove inline frame element - REMOVE
    text = re.sub(r'', '', text, flags=re.DOTALL)

     # Remove specified text
    patterns = r'\b(p|dataatomidbddcbffdabfcfcfbe|href|blockquote|span|class|element|element-image_caption|element-image_credit|figcaption|liststrong|Photo/Rodrigo|ADVERTISEMENT|element--supporting|Photo/Evgeniy|element-rich-link|copyright|element--showcase|AD-FREE,|meterActive/meterExpired|Photo/Vadim|VideoWhy|/PRNewswire/|itemV1|data-interactive|element-interactive|allowfullscreen="true"|data-atom-type="media"|element-atom|gu-atom|class="twitter-tweet"p|auto-generated|class="timezone"BST/span/time|class="quoted|class="gu-image"|class="/figcaption"|class="timezone"GMT/span/time|class="block"|data-block-contributor=""|class="block-elements"|class="element|href)\b'
    text = re.sub(patterns, '', text)
    
    # Remove 
    text = re.sub(r'', '', text)
    text = re.sub(r'', '', text)
    text = re.sub(r'', '', text)
    text = re.sub(r'/p', '', text)

    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    
    # Remove '@' symbols
    text = re.sub(r'@', '', text)
    
    # Remove links
    text = re.sub(r'http\S+', '', text)
    
    # Remove emojis
    text = text.encode('ascii', 'ignore').decode('ascii')
    
   
    return text

# %%
df['cleaned_corpus'] = df['Content'].apply(clean_text)

# %%
df.head()
# Out:
#         Date     Headline                                            Content  \
# 0 2024-06-07  www.bbc.com  How many people cross the Channel in small boa...
# 1 2024-06-07  www.bbc.com  Far right eyes Europe vote surge and ditches G...
# 2 2024-06-07  www.bbc.com  Greek court throws out shipwreck trial against...
# 3 2024-06-07  www.bbc.com  Migrants cross Channel for 10th consecutive da...
# 4 2024-06-07  www.bbc.com  More than 700 people arrive by small boats in ...
#
#   Source Country/Organization  \
# 0    BBC                   UK
# 1    BBC                   UK
# 2    BBC                   UK
# 3    BBC                   UK
# 4    BBC                   UK
#
#                                       cleaned_corpus
# 0  How many people cross the Channel in small boa...
# 1  Far right eyes Europe vote surge and ditches G...
# 2  Greek court throws out shipwreck trial against...
# 3  Migrants cross Channel for 10th consecutive da...
# 4  More than 700 people arrive by small boats in ...

# %%
df.tail()
# Out:
#            Date                                           Headline  \
# 2962 2021-04-22  Orange-bellied parrots leave Tasmania in bigge...
# 2963 2021-04-21  Melting ice in Arctic linked to bowhead whales...
# 2964 2021-03-01  A birder's calendar: where and when to watch A...
# 2965 2021-01-15  Air pollution will lead to mass migration, say...
# 2966 2021-01-17  In brief: Passing: An Alternative History of I...
#
#                                                 Content        Source  \
# 2962  <p>Nearly 200 endangered orange-bellied parrot...  The Guardian
# 2963  <p>As the ice melts at pace in the Arctic, the...  The Guardian
# 2964  <p>During Covid lockdown, birds in our backyar...  The Guardian
# 2965  <p>Air pollution does not respect national bou...  The Guardian
# 2966  <h2><strong><a href="https://guardianbookshop....  The Guardian
#
#      Country/Organization                                     cleaned_corpus
# 2962                   UK  Nearly 200 endangered orange-bellied parrots h...
# 2963                   UK  As the ice melts at pace in the Arctic, the mi...
# 2964                   UK  During Covid lockdown, birds in our backyards ...
# 2965                   UK  Air pollution does not respect national bounda...
# 2966                   UK  Passing: An Alternative History of IdentityLip...

# %%
df.to_csv("/Users/henryasiamah/Desktop/work/cleaned.csv", index=False)
